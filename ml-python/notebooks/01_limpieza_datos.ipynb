# %%
import pandas as pd
import os

# Buscamos el archivo en la ruta que ya conocemos
ruta = '../data/raw/Big_AHR.csv'

if os.path.exists(ruta):
    df = pd.read_csv(ruta)
    print("✅ ¡LOGRADO! El entorno funciona y el archivo se cargó.")
    print(f"Tienes {df.shape[0]} filas listas para analizar.")
    print("\nColumnas disponibles:")
    print(df.columns.tolist())
else:
    print("❌ El entorno está bien, pero no encuentro el archivo en la carpeta data/raw")
# Out:
# ✅ ¡LOGRADO! El entorno funciona y el archivo se cargó.
# Tienes 18172 filas listas para analizar.
#
# Columnas disponibles:
# ['Unnamed: 0', 'title', 'rating', 'review_text', 'location', 'hotel', 'label']
